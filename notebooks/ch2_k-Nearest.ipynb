# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set() # Plot styling
rand = np.random.RandomState(42)

# %%
X = rand.randint(0,10, size=(10,2))
print(X)
plt.scatter(X[:, 0], X[:, 1], s=100);
# Out:
# [[5 2]
#  [0 2]
#  [4 2]
#  [0 4]
#  [9 6]
#  [6 8]
#  [9 9]
#  [2 6]
#  [0 3]
#  [3 4]]

# %%
dist_sq = np.sum((X[:,np.newaxis,:] - X[np.newaxis,:,:]) ** 2, axis=-1)
np.round(np.sqrt(dist_sq))
# Out:
# array([[ 0.,  5.,  8.,  7.,  4.,  5.,  6.,  4.,  2.,  7.],
#        [ 5.,  0.,  9., 10.,  8.,  9.,  1.,  7.,  6.,  7.],
#        [ 8.,  9.,  0.,  2.,  5.,  4.,  9.,  4.,  6.,  3.],
#        [ 7., 10.,  2.,  0.,  4.,  3., 10.,  3.,  5.,  4.],
#        [ 4.,  8.,  5.,  4.,  0.,  1.,  9.,  2.,  2.,  6.],
#        [ 5.,  9.,  4.,  3.,  1.,  0., 10.,  2.,  3.,  6.],
#        [ 6.,  1.,  9., 10.,  9., 10.,  0.,  8.,  7.,  7.],
#        [ 4.,  7.,  4.,  3.,  2.,  2.,  8.,  0.,  2.,  4.],
#        [ 2.,  6.,  6.,  5.,  2.,  3.,  7.,  2.,  0.,  6.],
#        [ 7.,  7.,  3.,  4.,  6.,  6.,  7.,  4.,  6.,  0.]])
